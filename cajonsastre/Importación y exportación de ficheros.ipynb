# %%
import numpy as np
import pandas as pd

import requests
import json
import glob

# %% [markdown]
# ### Flat file

# %% [markdown]
# read_table(filepath_or_buffer[, sep, …]) Read general delimited file into DataFrame.

# %% [markdown]
# read_csv(filepath_or_buffer[, sep, …]) Read a comma-separated values (csv) file into DataFrame.

# %% [markdown]
# read_fwf(filepath_or_buffer[, colspecs, …]) Read a table of fixed-width formatted lines into DataFrame.

# %% [markdown]
# ### Clipboard

# %% [markdown]
# read_clipboard([sep]) Read text from clipboard and pass to read_csv.

# %% [markdown]
# ### Excel

# %% [markdown]
# read_excel() Read an Excel file into a pandas DataFrame.

# %%
xl = pd.ExcelFile('00 - datasets/TablasDinamicas.xlsx')
xl.sheet_names
# Out:
# ['PARQUES',
#  'STATION',
#  'PETITBAKERIE',
#  'ESPN',
#  'MAQUILLAJE',
#  'PARETO',
#  'TAPEDATA',
#  'STORES',
#  'STORES II',
#  'MADRID']

# %%
df = pd.read_excel(open('00 - datasets/TablasDinamicas.xlsx','rb'), sheet_name='PARQUES')
df
# Out:
#                       Parque     2001     2002     2003     2004     2005  \
# 0   Great Smoky Mountains NP  9197697  9316420  9366845  9167046  9192477
# 1            Grand Canyon NP  4104809  4001974  4124900  4326234  4401522
# 2                 Olympic NP  3416069  3691310  3225327  3073722  3142774
# 3                Yosemite NP  3368731  3361867  3378664  3280911  3304144
# 4          Rocky Mountain NP  3139685  2988475  3067256  2781899  2798368
# 5         Cuyahoga Valley NP  3123353  3217935  2879591  3306175  2533827
# 6             Yellowstone NP  2758526  2973677  3019375  2868317  2835651
# 7             Grand Teton NP  2535108  2612629  2355693  2360373  2463442
# 8                  Acadia NP  2516551  2558572  2431062  2207847  2051484
# 9                    Zion NP  2217779  2592545  2458792  2677342  2586665
# 10           Mammoth Cave NP  1883580  1891307  1869137  1888267  1878006
# 11                Glacier NP  1680614  1905689  1664046  2033933  1925101
# ...

# %%
df = pd.read_excel(open('00 - datasets/TablasDinamicas.xlsx','rb'), sheet_name=2)

# %% [markdown]
# ExcelFile.parse([sheet_name, header, names, …]) Parse specified sheet(s) into a DataFrame.

# %% [markdown]
# ExcelWriter(path[, engine])  Class for writing DataFrame objects into excel sheets.

# %%
to_excel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-08c44a3d239f> in <module>
# ----> 1 to_excel
#
# NameError: name 'to_excel' is not defined

# %% [markdown]
# https://stackoverflow.com/questions/28766133/faster-way-to-read-excel-files-to-pandas-dataframe

# %% [markdown]
# https://xlsxwriter.readthedocs.io/example_pandas_simple.html

# %% [markdown]
# ### JSON

# %%
patients = {
         "Name":{"0":"John","1":"Nick","2":"Ali","3":"Joseph"},
         "Gender":{"0":"Male","1":"Male","2":"Female","3":"Male"},
         "Nationality":{"0":"UK","1":"French","2":"USA","3":"Brazil"},
         "Age" :{"0":10,"1":25,"2":35,"3":29}
}
cars = [
    {"Name":"Honda", "Price": 10000, "Model":2005, "Power": 1300},
    {"Name":"Toyota", "Price": 12000, "Model":2010, "Power": 1600},
    {"Name":"Audi", "Price": 25000, "Model":2017, "Power": 1800},
    {"Name":"Ford", "Price": 28000, "Model":2009, "Power": 1200}]

with open('patients.json', 'w') as f:
    json.dump(patients, f)
    
with open('cars.json', 'w') as f:
    json.dump(cars, f)

# %%
url = "https://api.exchangerate-api.com/v4/latest/USD"
df = pd.read_json(url)
df

# %% [markdown]
# read_json() Convert a JSON string to pandas object.

# %%
df=pd.read_json('patients.json')
df

# %% [markdown]
# json_normalize(data[, record_path, meta, …])  Normalize semi-structured JSON data into a flat table.

# %% [markdown]
# build_table_schema(data[, index, …]) Create a Table schema from data.

# %% [markdown]
# ### HTML

# %% [markdown]
# read_html() Read HTML tables into a list of DataFrame objects.
#
# https://pbpython.com/pandas-html-table.html

# %%
table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')
df = table_MN[0]
df
# Out:
#                                             Minnesota  \
# 0                                               State
# 1                                  State of Minnesota
# 2                                            FlagSeal
# 3   Nickname(s): Land of 10,000 Lakes;North Star S...
# 4   Motto(s): L'Étoile du Nord (French: The Star o...
# 5                           Anthem: "Hail! Minnesota"
# 6   Map of the United States with Minnesota highli...
# 7                                             Country
# 8                                    Before statehood
# 9                               Admitted to the Union
# 10                                            Capital
# 11                                       Largest city
# 12                                      Largest metro
# 13                                         Government
# 14                                         • Governor
# 15                              • Lieutenant Governor
# ...

# %%
table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota', match='Election results from statewide races')
df=table_MN[0]
df
# Out:
#     Year     Office    GOP    DFL Others
# 0   2020  President  45.3%  52.4%   2.3%
# 1   2020    Senator  43.5%  48.8%   7.7%
# 2   2018   Governor  42.4%  53.9%   3.7%
# 3   2018    Senator  36.2%  60.3%   3.4%
# 4   2018    Senator  42.4%  53.0%   4.6%
# 5   2016  President  44.9%  46.4%   8.6%
# 6   2014   Governor  44.5%  50.1%   5.4%
# 7   2014    Senator  42.9%  53.2%   3.9%
# 8   2012  President  45.1%  52.8%   2.1%
# 9   2012    Senator  30.6%  65.3%   4.1%
# 10  2010   Governor  43.2%  43.7%  13.1%
# 11  2008  President  43.8%  54.1%   2.1%
# 12  2008    Senator  42.0%  42.0%  16.0%
# 13  2006   Governor  46.7%  45.7%   7.6%
# 14  2006    Senator  37.9%  58.1%   4.0%
# 15  2004  President  47.6%  51.1%   1.3%
# 16  2002   Governor  44.4%  33.5%  22.1%
# 17  2002    Senator  49.5%  47.3%   1.0%
# 18  2000  President  45.5%  47.9%   6.6%
# 19  2000    Senator  43.3%  48.8%   7.9%
# 20  1998   Governor  34.3%  28.1%  37.6%
# 21  1996  President  35.0%  51.1%  13.9%
# ...

# %% [markdown]
# ### Otros mecanismos

# %%
data = requests.get(
    'https://min-api.cryptocompare.com/data/histoday?fsym=BTC&tsym=ETH&limit=30&aggregate=1&e=CCCAGG').json()['Data']
df = pd.DataFrame.from_dict(data)
df.head()
# Out:
#          time   high    low   open  volumefrom    volumeto  close  \
# 0  1605744000  38.01  36.97  37.15    23621.92   887917.88  37.78
# 1  1605830400  37.85  35.84  37.78    38018.87  1396266.66  36.58
# 2  1605916800  36.89  33.82  36.58    39517.54  1400822.64  33.84
# 3  1606003200  34.44  32.11  33.84    48304.15  1617888.36  32.87
# 4  1606089600  32.92  30.18  32.87    61384.49  1927391.88  30.18
#
#   conversionType conversionSymbol
# 0         invert
# 1         invert
# 2         invert
# 3         invert
# 4         invert
