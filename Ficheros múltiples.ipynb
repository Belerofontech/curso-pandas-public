# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import pathlib as path

# %%
ruta = path.Path.cwd() / '00 - datasets' / 'data' / 'Anexado' / 'Sales_CSV'

# %%
def procesadora(ruta):
    df = (pd.read_csv(ruta)
          .drop(['Year', 'Month'], axis=1)
          )
    return df


all_files = list(ruta.glob('*.csv'))
dflist = (procesadora(f) for f in all_files)
df = pd.concat(dflist, ignore_index=True)
df
# Out:
#        ProductKey                OrderDate                 ShipDate  \
# 0             310  2006-01-01 00:00:00.000  2006-01-08 00:00:00.000
# 1             346  2006-01-01 00:00:00.000  2006-01-08 00:00:00.000
# 2             346  2006-01-01 00:00:00.000  2006-01-08 00:00:00.000
# 3             336  2006-01-01 00:00:00.000  2006-01-08 00:00:00.000
# 4             346  2006-01-01 00:00:00.000  2006-01-08 00:00:00.000
# ...           ...                      ...                      ...
# 58184         561  2008-12-30 00:00:00.000  2009-01-07 00:00:00.000
# 58185         584  2008-12-30 00:00:00.000  2009-01-07 00:00:00.000
# 58186         605  2008-12-30 00:00:00.000  2009-01-07 00:00:00.000
# 58187         538  2008-12-30 00:00:00.000  2009-01-07 00:00:00.000
# 58188         490  2008-12-30 00:00:00.000  2009-01-07 00:00:00.000
#
#        CustomerKey  PromotionKey  SalesTerritoryKey SalesOrderNumber  \
# 0            21768             1                  6          SO43697
# ...

# %%
df2.to_excel('C://Users//benit//Downloads//salida.xlsx')

# %%
tresmejores= df.loc[:, 'SalesOrderNumber'].value_counts().nlargest(10).index[:3]
df[df.SalesOrderNumber.isin(tresmejores)]
# Out:
#        ProductKey                OrderDate                 ShipDate  \
# 22722         596  2008-05-30 00:00:00.000  2008-06-07 00:00:00.000
# 22723         535  2008-05-30 00:00:00.000  2008-06-07 00:00:00.000
# 22724         528  2008-05-30 00:00:00.000  2008-06-07 00:00:00.000
# 22725         485  2008-05-30 00:00:00.000  2008-06-07 00:00:00.000
# 22726         478  2008-05-30 00:00:00.000  2008-06-07 00:00:00.000
# 22727         477  2008-05-30 00:00:00.000  2008-06-07 00:00:00.000
# 22728         217  2008-05-30 00:00:00.000  2008-06-07 00:00:00.000
# 22729         237  2008-05-30 00:00:00.000  2008-06-07 00:00:00.000
# 50004         359  2008-11-16 00:00:00.000  2008-11-23 00:00:00.000
# 50005         537  2008-11-16 00:00:00.000  2008-11-23 00:00:00.000
# 50006         528  2008-11-16 00:00:00.000  2008-11-23 00:00:00.000
# 50007         485  2008-11-16 00:00:00.000  2008-11-23 00:00:00.000
# 50008         477  2008-11-16 00:00:00.000  2008-11-23 00:00:00.000
# ...
