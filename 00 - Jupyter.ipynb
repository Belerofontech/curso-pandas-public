# %% [markdown]
# # Introducción a Jupyter
#
# * https://towardsdatascience.com/bringing-the-best-out-of-jupyter-notebooks-for-data-science-f0871519ca29

# %% [markdown]
# Importaciones adicionales
#
# * sidetable
# * pandas-profiling
#
# Buscar las rutas de instalación en conda e instalar los paquetes
# vacacion sin acento es un error de orgrufia

# %% [markdown]
# # Atajos principales

# %% [markdown]
# * a inserta un bloque antes del bloque actual
# * b inserta un bloque despues del bloque actual
# * se selecciona con shift y flechas
# * se ejecuta con ctrl + intro
# * m convierte el bloque en markdown
# * y convierte en bloque de calculo
# * ctrl + shift + p se obtiene desplegable de menus
#
# Revisión ortografica para Jupyter
# https://nicoguaro.github.io/posts/ortografia_jupyter/

# %% [markdown]
# # Introducción a markdown para Jupyter
#
# Ver comandos básicos y enlazar un tutorial.
# Realizar varios elementos
#
# https://sqlbak.com/blog/wp-content/uploads/2020/04/Jupyter-Notebook-Markdown-Cheatsheet.pdf

# %% [markdown]
# # Código

# %%
import numpy as np
import pandas as pd
import sidetable
from pandas_profiling import ProfileReport
import qgrid
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-bf0d7965ccdc> in <module>
#       2 import pandas as pd
#       3 import sidetable
# ----> 4 from pandas_profiling import ProfileReport
#       5 import qgrid
#
# ~\anaconda3\lib\site-packages\pandas_profiling\__init__.py in <module>
#       5
#       6 from pandas_profiling.config import Config, config
# ----> 7 from pandas_profiling.controller import pandas_decorator
#       8 from pandas_profiling.profile_report import ProfileReport
#       9 from pandas_profiling.version import __version__
#
# ~\anaconda3\lib\site-packages\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.__init__ import ProfileReport
#       5
#       6
#
# ~\anaconda3\lib\site-packages\pandas_profiling\__init__.py in <module>
#       6 from pandas_profiling.config import Config, config
#       7 from pandas_profiling.controller import pandas_decorator
# ----> 8 from pandas_profiling.profile_report import ProfileReport
#       9 from pandas_profiling.version import __version__
#      10
#
# ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py in <module>
#       9
#      10 from pandas_profiling.config import config
# ---> 11 from pandas_profiling.model.describe import describe as describe_df
#      12 from pandas_profiling.model.messages import MessageType
#      13 from pandas_profiling.report import get_report_structure
#
# ~\anaconda3\lib\site-packages\pandas_profiling\model\describe.py in <module>
#      11 from pandas_profiling.model.correlations import calculate_correlation
#      12 from pandas_profiling.model.sample import Sample, get_sample
# ---> 13 from pandas_profiling.model.summary import (
#      14     get_duplicates,
#      15     get_messages,
#
# ~\anaconda3\lib\site-packages\pandas_profiling\model\summary.py in <module>
#      32     warning_type_date,
#      33 )
# ---> 34 from pandas_profiling.visualisation.missing import (
#      35     missing_bar,
#      36     missing_dendrogram,
#
# ~\anaconda3\lib\site-packages\pandas_profiling\visualisation\missing.py in <module>
#       2 import pandas as pd
#       3 from matplotlib import pyplot as plt
# ----> 4 from missingno import missingno
#       5
#       6 from pandas_profiling.config import config
#
# ~\anaconda3\lib\site-packages\missingno\__init__.py in <module>
# ----> 1 from .missingno import matrix
#       2 from .missingno import bar
#       3 from .missingno import heatmap
#       4 from .missingno import dendrogram
#       5 from .missingno import geoplot
#
# ~\anaconda3\lib\site-packages\missingno\missingno.py in <module>
#       4 import matplotlib.pyplot as plt
#       5 from scipy.cluster import hierarchy
# ----> 6 import seaborn as sns
#       7 import pandas as pd
#       8 from .utils import nullity_filter, nullity_sort
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df=sns.load_dataset('mpg')

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %% [markdown]
# ## sidetable

# %% [markdown]
# https://github.com/chris1610/sidetable

# %%
df.stb.missing(style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >missing</th>        <th class="col_heading level0 col1" >total</th>        <th class="col_heading level0 col2" >percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793clevel0_row0" class="row_heading level0 row0" >horsepower</th>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow0_col0" class="data row0 col0" >6</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow0_col1" class="data row0 col1" >398</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow0_col2" class="data row0 col2" >1.51%</td>
#             </tr>
#             <tr>
#                         <th id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793clevel0_row1" class="row_heading level0 row1" >mpg</th>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow1_col1" class="data row1 col1" >398</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow1_col2" class="data row1 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793clevel0_row2" class="row_heading level0 row2" >cylinders</th>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow2_col0" class="data row2 col0" >0</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow2_col1" class="data row2 col1" >398</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow2_col2" class="data row2 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793clevel0_row3" class="row_heading level0 row3" >displacement</th>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow3_col0" class="data row3 col0" >0</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow3_col1" class="data row3 col1" >398</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow3_col2" class="data row3 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793clevel0_row4" class="row_heading level0 row4" >weight</th>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow4_col0" class="data row4 col0" >0</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow4_col1" class="data row4 col1" >398</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow4_col2" class="data row4 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793clevel0_row5" class="row_heading level0 row5" >acceleration</th>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow5_col1" class="data row5 col1" >398</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow5_col2" class="data row5 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793clevel0_row6" class="row_heading level0 row6" >model_year</th>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow6_col0" class="data row6 col0" >0</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow6_col1" class="data row6 col1" >398</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow6_col2" class="data row6 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793clevel0_row7" class="row_heading level0 row7" >origin</th>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow7_col0" class="data row7 col0" >0</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow7_col1" class="data row7 col1" >398</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow7_col2" class="data row7 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793clevel0_row8" class="row_heading level0 row8" >name</th>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow8_col0" class="data row8 col0" >0</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow8_col1" class="data row8 col1" >398</td>
#                         <td id="T_e13fa929_3880_11eb_acc2_f8a2d6b6793crow8_col2" class="data row8 col2" >0.00%</td>
#             </tr>
#     </tbody></table>

# %%
df.stb.counts(exclude='mpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-2c3c84d024fe> in <module>
# ----> 1 df.stb.counts(exclude='mpg')
#
# ~\anaconda3\lib\site-packages\sidetable\sidetable.py in counts(self, include, exclude, sort_ascending, sort_col)
#     245         # Pass the include and exclude values to select_dtypes
#     246         else:
# --> 247             cols_to_use = self._obj.select_dtypes(include=include,
#     248                                                   exclude=exclude).columns
#     249
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3566         # convert the myriad valid dtypes object to a single representation
#    3567         include = frozenset(infer_dtype_from_object(x) for x in include)
# -> 3568         exclude = frozenset(infer_dtype_from_object(x) for x in exclude)
#    3569         for dtypes in (include, exclude):
#    3570             invalidate_string_dtypes(dtypes)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in <genexpr>(.0)
#    3566         # convert the myriad valid dtypes object to a single representation
#    3567         include = frozenset(infer_dtype_from_object(x) for x in include)
# -> 3568         exclude = frozenset(infer_dtype_from_object(x) for x in exclude)
#    3569         for dtypes in (include, exclude):
#    3570             invalidate_string_dtypes(dtypes)
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\common.py in infer_dtype_from_object(dtype)
#    1702             pass
#    1703
# -> 1704     return infer_dtype_from_object(np.dtype(dtype))
#    1705
#    1706
#
# TypeError: data type 'mpg' not understood

# %%
df.stb.freq(['name'], value='weight', style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_437e27b2_3881_11eb_949f_f8a2d6b6793c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >weight</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_weight</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_437e27b2_3881_11eb_949f_f8a2d6b6793clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow0_col0" class="data row0 col0" >amc matador</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow0_col1" class="data row0 col1" >18,284</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow0_col2" class="data row0 col2" >1.55%</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow0_col3" class="data row0 col3" >18,284</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow0_col4" class="data row0 col4" >1.55%</td>
#             </tr>
#             <tr>
#                         <th id="T_437e27b2_3881_11eb_949f_f8a2d6b6793clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow1_col0" class="data row1 col0" >chevrolet impala</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow1_col1" class="data row1 col1" >17,834</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow1_col2" class="data row1 col2" >1.51%</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow1_col3" class="data row1 col3" >36,118</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow1_col4" class="data row1 col4" >3.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_437e27b2_3881_11eb_949f_f8a2d6b6793clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow2_col0" class="data row2 col0" >ford pinto</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow2_col1" class="data row2 col1" >14,995</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow2_col2" class="data row2 col2" >1.27%</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow2_col3" class="data row2 col3" >51,113</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow2_col4" class="data row2 col4" >4.32%</td>
#             </tr>
#             <tr>
#                         <th id="T_437e27b2_3881_11eb_949f_f8a2d6b6793clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow3_col0" class="data row3 col0" >ford maverick</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow3_col1" class="data row3 col1" >14,653</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow3_col2" class="data row3 col2" >1.24%</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow3_col3" class="data row3 col3" >65,766</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow3_col4" class="data row3 col4" >5.56%</td>
#             </tr>
#             <tr>
#                         <th id="T_437e27b2_3881_11eb_949f_f8a2d6b6793clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow4_col0" class="data row4 col0" >pontiac catalina</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow4_col1" class="data row4 col1" >13,478</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow4_col2" class="data row4 col2" >1.14%</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow4_col3" class="data row4 col3" >79,244</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow4_col4" class="data row4 col4" >6.70%</td>
#             </tr>
#             <tr>
#                         <th id="T_437e27b2_3881_11eb_949f_f8a2d6b6793clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow5_col0" class="data row5 col0" >ford galaxie 500</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow5_col1" class="data row5 col1" >12,624</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow5_col2" class="data row5 col2" >1.07%</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow5_col3" class="data row5 col3" >91,868</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow5_col4" class="data row5 col4" >7.77%</td>
#             </tr>
#             <tr>
#                         <th id="T_437e27b2_3881_11eb_949f_f8a2d6b6793clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow6_col0" class="data row6 col0" >plymouth fury iii</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow6_col1" class="data row6 col1" >12,543</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow6_col2" class="data row6 col2" >1.06%</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow6_col3" class="data row6 col3" >104,411</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow6_col4" class="data row6 col4" >8.83%</td>
#             </tr>
#             <tr>
#                         <th id="T_437e27b2_3881_11eb_949f_f8a2d6b6793clevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow7_col0" class="data row7 col0" >ford gran torino</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow7_col1" class="data row7 col1" >12,398</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow7_col2" class="data row7 col2" >1.05%</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow7_col3" class="data row7 col3" >116,809</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow7_col4" class="data row7 col4" >9.88%</td>
#             </tr>
#             <tr>
#                         <th id="T_437e27b2_3881_11eb_949f_f8a2d6b6793clevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow8_col0" class="data row8 col0" >chevrolet caprice classic</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow8_col1" class="data row8 col1" >12,184</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow8_col2" class="data row8 col2" >1.03%</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow8_col3" class="data row8 col3" >128,993</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow8_col4" class="data row8 col4" >10.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_437e27b2_3881_11eb_949f_f8a2d6b6793clevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow9_col0" class="data row9 col0" >peugeot 504</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow9_col1" class="data row9 col1" >12,089</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow9_col2" class="data row9 col2" >1.02%</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow9_col3" class="data row9 col3" >141,082</td>
#                         <td id="T_437e27b2_3881_11eb_949f_f8a2d6b6793crow9_col4" class="data row9 col4" >11.93%</td>
#             </tr>
#             <tr>

# %%
df.stb.subtotal()
# Out:
#                 mpg  cylinders  displacement  horsepower     weight  \
# 0              18.0        8.0         307.0       130.0     3504.0
# 1              15.0        8.0         350.0       165.0     3693.0
# 2              18.0        8.0         318.0       150.0     3436.0
# 3              16.0        8.0         304.0       150.0     3433.0
# 4              17.0        8.0         302.0       140.0     3449.0
# ...             ...        ...           ...         ...        ...
# 394            44.0        4.0          97.0        52.0     2130.0
# 395            32.0        4.0         135.0        84.0     2295.0
# 396            28.0        4.0         120.0        79.0     2625.0
# 397            31.0        4.0         119.0        82.0     2720.0
# grand_total  9358.8     2171.0       76983.5     40952.0  1182229.0
#
#              acceleration  model_year  origin                       name
# 0                    12.0        70.0     usa  chevrolet chevelle malibu
# 1                    11.5        70.0     usa          buick skylark 320
# 2                    11.0        70.0     usa         plymouth satellite
# 3                    12.0        70.0     usa              amc rebel sst
# 4                    10.5        70.0     usa                ford torino
# ...                   ...         ...     ...                        ...
# 394                  24.6        82.0  europe                  vw pickup
# 395                  11.6        82.0     usa              dodge rampage
# 396                  18.6        82.0     usa                ford ranger
# 397                  19.4        82.0     usa                 chevy s-10
# grand_total        6196.1     30252.0     NaN                        NaN
#
# [399 rows x 9 columns]

# %%
qcut

# %% [markdown]
# ## Pandas Profiling

# %% [markdown]
# https://github.com/pandas-profiling/pandas-profiling

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_widgets()
# Out:
# HBox(children=(HTML(value='Summarize dataset'), FloatProgress(value=0.0, max=23.0), HTML(value='')))
# HBox(children=(HTML(value='Generate report structure'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Render widgets'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# ## qgrid

# %%
grid=qgrid.show_grid(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5c83398846e4> in <module>
# ----> 1 grid=qgrid.show_grid(df)
#
# NameError: name 'qgrid' is not defined
