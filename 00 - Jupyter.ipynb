# %% [markdown]
# # Introducción a Jupyter
#
# * https://towardsdatascience.com/bringing-the-best-out-of-jupyter-notebooks-for-data-science-f0871519ca29

# %% [markdown]
# Importaciones adicionales
#
# * sidetable
# * pandas-profiling
# * qgrid
# * extensiones de notebook
#
# Para instalación de nuevos paquetes utilizar, buscar las restantes
# * conda install -c conda-forge sidetable
# * conda install -c conda-forge pandas-profiling
# * conda install -c conda-forge qgrid

# %% [markdown]
# # Atajos principales

# %% [markdown]
# * a inserta un bloque antes del bloque actual
# * b inserta un bloque despues del bloque actual
# * se selecciona con shift y flechas
# * se ejecuta con ctrl + intro
# * m convierte el bloque en markdown
# * y convierte en bloque de calculo
# * ctrl + shift + p se obtiene desplegable de menus
#
# Revisión ortografica para Jupyter
# https://nicoguaro.github.io/posts/ortografia_jupyter/

# %% [markdown]
# # Introducción a markdown para Jupyter
#
# Ver comandos básicos y enlazar un tutorial.
# Realizar varios elementos
#
# https://sqlbak.com/blog/wp-content/uploads/2020/04/Jupyter-Notebook-Markdown-Cheatsheet.pdf

# %% [markdown]
# # Código

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sidetable
from pandas_profiling import ProfileReport
import qgrid

# %%
pd.show_versions()
print('\n')
print('Pandas: ', pd.__version__)
print('Numpy: ', np.__version__)
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : db08276bc116c438d3fdee492026f8223584c477
# python           : 3.8.5.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.19041
# machine          : AMD64
# processor        : Intel64 Family 6 Model 61 Stepping 4, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : es_ES.cp1252
#
# pandas           : 1.1.3
# numpy            : 1.19.2
# pytz             : 2020.1
# dateutil         : 2.8.1
# pip              : 20.2.4
# setuptools       : 50.3.1.post20201107
# Cython           : 0.29.21
# pytest           : 6.1.1
# hypothesis       : None
# sphinx           : 3.2.1
# blosc            : None
# feather          : None
# xlsxwriter       : 1.3.7
# lxml.etree       : 4.6.1
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.2
# IPython          : 7.19.0
# ...

# %%
df=sns.load_dataset('mpg')

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %% [markdown]
# ## sidetable

# %% [markdown]
# La información de sidetable se encuentra en la web de pbpython.com y este es el git
# https://github.com/chris1610/sidetable

# %%
df.stb.missing(style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_23352a2f_4140_11eb_bbc7_648099851186" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >missing</th>        <th class="col_heading level0 col1" >total</th>        <th class="col_heading level0 col2" >percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23352a2f_4140_11eb_bbc7_648099851186level0_row0" class="row_heading level0 row0" >horsepower</th>
#                         <td id="T_23352a2f_4140_11eb_bbc7_648099851186row0_col0" class="data row0 col0" >6</td>
#                         <td id="T_23352a2f_4140_11eb_bbc7_648099851186row0_col1" class="data row0 col1" >398</td>
#                         <td id="T_23352a2f_4140_11eb_bbc7_648099851186row0_col2" class="data row0 col2" >1.51%</td>
#             </tr>
#             <tr>
# ...

# %%
df.stb.counts()
# Out:
#               count  unique   most_freq  most_freq_count       least_freq  \
# origin          398       3         usa              249           europe
# cylinders       398       5           4              204                5
# model_year      398      13          73               40               74
# displacement    398      82          97               21              104
# horsepower      392      93         150               22              210
# acceleration    398      95        14.5               23             22.1
# mpg             398     129          13               20             26.4
# name            398     305  ford pinto                6  renault 12 (sw)
# weight          398     351        1985                4             2000
#
#               least_freq_count
# origin                      70
# cylinders                    3
# model_year                  27
# displacement                 1
# horsepower                   1
# acceleration                 1
# ...

# %%
df.stb.freq(['name'], value='weight', style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_2bb0b54b_4140_11eb_a582_648099851186" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >weight</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_weight</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2bb0b54b_4140_11eb_a582_648099851186level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2bb0b54b_4140_11eb_a582_648099851186row0_col0" class="data row0 col0" >amc matador</td>
#                         <td id="T_2bb0b54b_4140_11eb_a582_648099851186row0_col1" class="data row0 col1" >18,284</td>
#                         <td id="T_2bb0b54b_4140_11eb_a582_648099851186row0_col2" class="data row0 col2" >1.55%</td>
# ...

# %%
df.stb.subtotal()
# Out:
#                 mpg  cylinders  displacement  horsepower     weight  \
# 0              18.0        8.0         307.0       130.0     3504.0
# 1              15.0        8.0         350.0       165.0     3693.0
# 2              18.0        8.0         318.0       150.0     3436.0
# 3              16.0        8.0         304.0       150.0     3433.0
# 4              17.0        8.0         302.0       140.0     3449.0
# ...             ...        ...           ...         ...        ...
# 394            44.0        4.0          97.0        52.0     2130.0
# 395            32.0        4.0         135.0        84.0     2295.0
# 396            28.0        4.0         120.0        79.0     2625.0
# 397            31.0        4.0         119.0        82.0     2720.0
# grand_total  9358.8     2171.0       76983.5     40952.0  1182229.0
#
#              acceleration  model_year  origin                       name
# 0                    12.0        70.0     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## Pandas Profiling

# %% [markdown]
# https://github.com/pandas-profiling/pandas-profiling

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_widgets()
# Out:
# ...
# Generate report structure: 100%|██████████| 1/1 [00:06<00:00,  6.63s/it]
# ...

# %% [markdown]
# ## qgrid

# %%
grid=qgrid.show_grid(df)
